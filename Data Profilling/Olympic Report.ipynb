# %%
import pandas as pd
import pandas_profiling as pf

# %%
df = pd.read_csv(r'G:\Revature Training\Projects\Project_1\athlete_events_data.csv',index_col='ID')
df.head()
# Out:
#                         Name Sex  Age  Height  Weight            Team  NOC  \
# ID
# 1                  A Dijiang   M   24     180    80.0           China  CHN
# 2                   A Lamusi   M   23     170    60.0           China  CHN
# 3        Gunnar Nielsen Aaby   M   24       0     0.0         Denmark  DEN
# 4       Edgar Lindenau Aabye   M   34       0     0.0  Denmark/Sweden  DEN
# 5   Christine Jacoba Aaftink   F   21     185    82.0     Netherlands  NED
#
#           Games  Year  Season       City          Sport  \
# ID
# 1   1992 Summer  1992  Summer  Barcelona     Basketball
# 2   2012 Summer  2012  Summer     London           Judo
# 3   1920 Summer  1920  Summer  Antwerpen       Football
# 4   1900 Summer  1900  Summer      Paris     Tug-Of-War
# 5   1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               Event Medal
# ID
# 1        Basketball Mens Basketball   NaN
# 2       Judo Mens Extra-Lightweight   NaN
# ...

# %%
record = pf.ProfileReport(df)

# %%
record.to_file("olympic_report.html")
